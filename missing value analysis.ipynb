# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/Vikash Singh/Desktop/r and python/data/ufo.csv")

# %%
data.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
data.iloc[:,0:5].isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
pd.Series([True,False,True]).sum()
# Out:
# 2

# %%
data=data.drop(['Colors Reported'],axis=1)

# %%
data.dropna(how='any').shape
# Out:
# (15576, 4)

# %%
data.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 4)

# %%
data.iloc[:,]
# Out:
#                        City Shape Reported State              Time
# 0                    Ithaca       TRIANGLE    NY    6/1/1930 22:00
# 1               Willingboro          OTHER    NJ   6/30/1930 20:00
# 2                   Holyoke           OVAL    CO   2/15/1931 14:00
# 3                   Abilene           DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair          LIGHT    NY   4/18/1933 19:00
# 5               Valley City           DISK    ND   9/15/1934 15:30
# 6               Crater Lake         CIRCLE    CA    6/15/1935 0:00
# 7                      Alma           DISK    MI    7/15/1936 0:00
# 8                   Eklutna          CIGAR    AK  10/15/1936 17:00
# 9                   Hubbard       CYLINDER    OR    6/15/1937 0:00
# 10                  Fontana          LIGHT    CA   8/15/1937 21:00
# 11                 Waterloo       FIREBALL    AL    6/1/1939 20:00
# 12                   Belton         SPHERE    SC   6/30/1939 20:00
# ...
